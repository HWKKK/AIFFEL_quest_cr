# %% [markdown]
# <a href="https://colab.research.google.com/github/HWKKK/AIFFEL_quest_cr/blob/main/Python/Py02/Quest01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("/Avengers.txt", 'r')
data = f.read()

#1-1. 모든 문자를 소문자로 변환
lower_data = data.lower()

#1-2. 모든 기호를 제거한다.
t_text = lower_data.replace(".\n", " ") #나중에 다시 보기
t_text = t_text.replace("-", "")
t_text = t_text.replace(".", "") #문장 마지막에 있는 마침표는 줄바꿈과 합쳐졌을 수 있음
t_text = t_text.replace(",", "")
t_text = t_text.replace("?", "")
t_text = t_text.replace("!", "")
t_text = t_text.replace("'s", " is")
t_text = t_text.replace("n't", " not")
t_text = t_text.replace("'m", " am")
t_text = t_text.replace("'re", " are")
t_text = t_text.replace("'ll", " will")
t_text = t_text.replace("'d", " would")
t_text = t_text.replace("'ve", " have")


#1-3. 단어 단위로 분리한다.
temp_list = t_text.split(" ")


#2. 각 단어 별 빈도수를 딕셔너리 형태로 저장한다.
t_dict = {} #빈 딕셔너리를 하나 생성한다.
for i in range(0,len(temp_list)): #리스트 요소값 확인
  if temp_list[i] not in t_dict: #만약, 현재 요소 값이 딕셔너리 안에 없다면
    t_dict.update({temp_list[i]:1}) #딕셔너리의 키로 새로 생성하고, 키의 발견 횟수를 1로 저장한다
  else:
    new_cnt = t_dict[temp_list[i]] + 1
    t_dict.update({temp_list[i]:new_cnt}) #새로운 빈도수로 dict 업데이트


#3. 딕셔너리를 빈도수순으로 내림차순 정렬하고, 정렬 순서대로 정수 인덱스를 부여한다.
t_dict_sorted = sorted(t_dict,key=lambda x:t_dict[x], reverse=True)


#4. 텍스트를 input()으로 입력받아서 정수를 return하는 함수를 만든다.
text = input("텍스트 입력: ")
t_text = text.split(" ")
result = []
for t in t_text:
  result_rank = t_dict_sorted.index(t)+1
  result.append(result_rank)
# Out:
# {'the': 352, 'tesseract': 29, 'has': 20, 'awakened': 1, 'it': 156, 'is': 336, 'on': 95, 'a': 215, 'neutral': 1, 'world': 22, 'human': 2, 'they': 39, 'wield': 2, 'its': 5, 'power\nbut': 1, 'our': 20, 'ally': 1, 'knows': 8, 'working': 5, 'so': 31, 'that': 134, 'never': 10, 'will': 59, 'learn': 1, 'he': 102, 'ready': 5, 'to': 214, 'lead': 4, 'and': 96, 'force': 6, 'chitauri': 3, 'follow': 2, 'be': 63, 'his': 30, 'universe': 2, 'yours': 2, 'humans': 4, 'what': 69, 'can': 36, 'do': 89, 'but': 31, 'burn': 1, 'how': 32, 'bad': 3, 'it\nthat': 1, 'problem': 2, 'sir': 20, 'we': 131, 'not': 209, 'know': 54, 'dr': 9, 'selvig': 9, 'read': 3, 'an': 34, 'energy': 12, 'surge': 1, 'from': 25, 'four': 2, 'hour': 2, 'ago': 1, 'nasa': 1, 'did': 63, 'authorize': 1, 'pull': 3, 'test': 3, 'phase': 5, 'was': 50, 'testing': 1, 'even': 8, 'in': 92, 'room': 3, 'spontaneous': 1, 'advancement\nit': 1, 'just': 31, 'turned': 1, 'itself': 4, 'on\nwhat': 1, 'are': 119, 'engine': 10, 'levels': 3, 'now\nclimbing': 1, 'when': 15, 'could': 14, 'shut': 8, 'down': 25, 'ordered': 1, 'evac': 2, 'long': 7, 'get': 41, 'everyone': 4, 'out\ncampus': 1, 'should': 23, 'clear': 4, 'next': 6, 'half': 2, 'better': 7, 'evacuation': 1, 'maybe': 6, 'futile': 1, 'tell': 18, 'them': 27, 'go': 14, 'back': 18, 'sleep\nif': 1, 'ca': 19, 'control': 7, 'energy\nthere': 1, 'may': 8, 'minimum': 1, 'safe': 2, 'distance': 2, 'i': 298, 'need': 41, 'you': 372, 'make': 10, 'sure': 6, 'phase\nsir': 1, 'really': 11, 'priority': 1, 'right': 21, 'now\nuntil': 1, 'such': 1, 'time': 15, 'as': 24, 'ends\nwe': 1, 'act': 2, 'though': 6, 'intends': 1, 'spin': 1, 'out': 49, 'tech': 1, 'below': 1, 'every': 10, 'piece': 2, 'of': 120, '2': 3, 'truck': 1, 'gone': 4, 'yes': 8, 'come': 27, 'with': 33, 'me': 64, 'talk': 6, 'doctor': 11, '': 360, 'director': 10, 'there': 38, 'anything': 9, 'for': 68, 'certain\n': 1, 'misbehaving': 1, 'supposed': 3, 'funny\nno': 1, 'funny': 2, 'at': 17, 'all': 39, 'only': 14, 'active': 1, 'she': 7, 'ismisbehaving': 1, 'soon': 3, 'until': 8, 'plug\nshe': 1, 'source': 5, 'if': 36, 'turn': 8, 'off': 15, 'power': 13, 'turns': 2, 'reaches': 1, 'peak': 1, 'level': 3, 'have': 100, 'prepared': 3, 'this': 81, 'harnessing': 1, 'space': 5, 'harness': 1, 'calculations': 1, 'far': 6, 'complete': 1, 'now': 23, 'throwing': 1, 'interference': 1, 'radiation\nnothing': 1, 'harmful': 2, 'low': 2, 'gamma': 5, 'radiation': 3, 'where': 21, 'agent': 16, 'barton\nthe': 1, 'hawk': 1, 'up': 35, 'nest': 1, 'usual': 1, 'barton': 11, 'report': 1, 'gave': 2, 'detail': 1, 'could\nkeep': 1, 'close': 11, 'eye': 3, 'things': 8, 'see': 14, 'seeing': 4, 'might\n': 1, 'set': 4, 'thing': 10, 'off\n': 2, 'spiking': 1, 'again': 3, 'no': 51, 'one': 22, 'or': 9, 'oven': 1, 'clean': 3, 'contacts': 1, 'im': 1, 'any': 8, 'tampering': 1, 'end': 10, 'end\n': 1, 'cube': 14, 'door': 2, 'yeah': 16, 'doorway': 1, 'other': 12, 'doors': 1, 'open': 5, 'both': 1, 'sides': 1, 'please': 8, 'put': 23, 'spear\nyou': 1, 'heart': 3, 'still': 10, 'does': 19, 'messier': 1, 'course': 3, 'too': 10, 'else': 3, 'am': 63, 'loki': 43, 'asgard\n': 2, 'burdened': 1, 'glorious': 3, 'purpose': 1, 'brother': 6, 'thor\nwe': 1, 'quarrel': 2, 'your': 44, 'people': 16, 'ant': 1, 'boot': 2, 'planning': 2, 'step': 3, 'us\n': 1, 'glad': 2, 'tidings\n': 1, 'made': 13, 'free': 4, 'what\nfreedom': 1, 'freedom': 2, 'life': 6, 'great': 3, 'lie': 2, 'once': 6, 'accept': 1, 'peace': 4, 'say': 10, 'kind': 7, 'of\nthink': 1, 'mean': 14, 'fury': 16, 'stalling': 2, 'place': 5, 'about': 32, 'blow\ndrop': 1, 'hundred': 3, 'feet': 2, 'raw': 2, 'material\nhe': 1, 'means': 6, 'bury': 1, 'us': 23, 'like': 37, 'pharaohs': 1, 'odin': 2, 'portal': 9, 'collapsing': 1, 'got': 38, 'two': 4, 'minutes': 2, 'before': 7, 'goes': 2, 'critical': 1, 'drop': 3, 'him': 25, 'these': 11, 'vehicles': 1, 'who': 16, 'that\n': 4, 'hill': 1, 'copy': 2, 'track': 2, 'down\nets': 1, 'leave': 6, 'cleared': 1, 'upstairs': 1, 'copy\nthe': 1, 'hostile': 3, 'men': 8, 'hill\na': 1, 'lot': 10, 'under\ndo': ...
# ['you', '', 'the', 'is', 'i', 'a', 'to', 'not', 'it', 'that', 'we', 'of', 'are', 'he', 'have', 'and', 'on', 'in', 'do', 'this', 'what', 'for', 'me', 'be', 'did', 'am', 'will', 'know', 'no', 'was', 'out', 'your', 'loki', 'get', 'need', 'my', 'they', 'all', 'there', 'got', 'like', 'can', 'if', 'up', 'an', 'with', 'how', 'about', 'so', 'but', 'just', 'think', 'gonna', 'would', 'his', 'tesseract', 'here', 'stark', 'them', 'come', 'well', 'from', 'down', 'him', 'as', 'should', 'now', 'put', 'us', 'world', 'one', 'right', 'where', 'has', 'our', 'sir', 'ca', 'does', 'guy', 'tell', 'back', 'way', 'were', 'at', 'why', 'agent', 'yeah', 'people', 'fury', 'who', 'let', 'man', 'when', 'time', 'off', 'take', 'could', 'go', 'only', 'see', 'cube', 'mean', 'want', 'banner', 'then', 'good', 'power', 'made', 'everything', 'shield', 'some', 'wanna', 'energy', 'other', 'war', 'been', 'oh', 'find', 'wants', 'little', 'really', 'doctor', 'barton', 'close', 'these', 'more', 'into', 'gotta', 'call', 'never', 'engine', 'make', 'every', 'director', 'thing', 'end', 'still', 'too', 'say', 'lot', 'by', 'thought', 'work', 'sorry', 'dr', 'selvig', 'anything', 'or', 'portal', 'than', 'had', 'something', 'stay', 'much', 'doing', 'knows', 'even', 'shut', 'may', 'yes', 'until', 'turn', 'things', 'any', 'please', 'men', 'give', 'look', 'hold', 'big', 'keep', 'very', 'point', 'yourself', 'might', 'captain', 'suit', 'long', 'better', 'control', 'she', 'kind', 'before', 'coulson', 'pretty', 'away', 'lost', 'try', 'after', 'stop', 'ever', 'over', 'team', 'seen', 'around', 'going', 'love', 'thank', 'earth', 'coming', 'hit', 'together', 'okay', 'army', 'force', 'next', 'maybe', 'sure', 'though', 'talk', 'far', 'brother', 'life', 'once', 'means', 'leave', 'first', 'god', 'needs', 'asgard', 'thor', 'which', 'avengers', 'remember', 'phil', 'alright', 'plan', 'guys', 'done', 'because', 'hulk', 'fight', 'its', 'working', 'ready', 'phase', 'source', 'space', 'gamma', 'open', 'place', 'many', 'true', 'takes', 'eyes', 'spy', 'romanoff', 'miss', 'wipe', 'planet', 'line', 'won', 'save', 'you\n', 'rest', 'jarvis', 'percent', 'name', 'nothing', 'hard', 'new', 'word', 'always', 'none', 'their', 'run', 'lead', 'humans', 'itself', 'everyone', 'clear', 'gone', 'seeing', 'set', 'free', 'peace', 'two', 'that\n', 'without', 'fall', 'feel', 'listen', 'blow', 'father', 'secret', 'start', 'kill', 'seems', 'says', 'those', 'it\n', 'use', 'enough', 'trying', 'took', 'bring', 'already', 'wrong', 'left', 'become', 'self', 'actually', 'came', 'tower', 'twelve', 'mr', 'play', 'whatever', 'last', 'used', 'while', 'huge', 'against', 'scepter', 'yet', 'me\n', 'thanks', 'show', 'target', 'another', 'son', 'built', 'wo', 'through', 'lose', 'understand', 'armor', 'three', 'perimeter', 'heroes', 'chitauri', 'bad', 'read', 'pull', 'test', 'room', 'levels', '2', 'supposed', 'soon', 'level', 'prepared', 'radiation', 'eye', 'again', 'clean', 'heart', 'course', 'else', 'glorious', 'step', 'great', 'hundred', 'drop', 'hostile', 'living', 'looking', 'running', 'face', 'ask', 'here\n', 'wake', 'hell', 'city', 'whole', 'me\nwe', 'kept', 'why\n', 'break', 'told', 'stand', 'alone', 'intelligence', 'exactly', 'initiative', 'security', 'water', 'under', 'weapon', 'called', 'ten', 'light', 'moment', 'being', 'tony', 'having', 'moved', 'person', 'meet', 'ice', 'hope', 'job', 'old', 'king', 'full', 'beyond', 'threaten', 'pain', 'rogers', 'care', 'minute', 'worse', 'lets', 'asking', 'hands', 'lab', 'few', 'stuff', 'iridium', 'truth', 'couple', 'match', 'kneel', 'attack', 'tesseract\n', 'king\n', 'threat', 'sent', 'idea', 'makes', 'desperate', 'fun', 'building', 'erik', 'speak', 'someone', 'monster', 'tried', 'focused', 'nice', 'taking', 'changed', 'him\n', 'red', 'change', 'stark\n', 'same', 'weapons', 'slow', 'this\n', 'wait', 'needed', 'party', 'send', 'soldier', 'late', 'council', 'human', 'wield', 'follow', 'universe', 'yours', 'problem', 'four', 'hour', 'evac', 'half', 'safe', 'distance', 'act', 'piece', 'funny', ' ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-0a374ad53bf0> in <cell line: 42>()
#      40
#      41 #4. 텍스트를 input()으로 입력받아서 정수를 return하는 함수를 만든다.
# ---> 42 text = input("텍스트 입력: ")
#      43 t_text = text.split(" ")
#      44 result = []
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
